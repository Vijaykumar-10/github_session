# %%
a=10
b=20
c=a+b
print(c) # shift+enter at a time
# Out:
# 30

# %%
n1=100
n1
# Out:
# 100

# %%
a=10
b=20
a
b # by default python will give last value show
# Out:
# 20

# %%
a=10
b=20
print(a)
print(b) # if you want show both values can do print
# Out:
# 10
# 20

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
a=10
b=20
a,b
# Out:
# (10, 20)

# %%
a=10
b=20
print(a),print(b)
# Out:
# 10
# 20
# (None, None)

# %%
hello today im learing python
# Out:
#   Cell In[9], line 1
#     hello today im learing python
#           ^
# SyntaxError: invalid syntax

# %%
"hello today im learing python"
# Out:
# 'hello today im learing python'

# %% [markdown]
# Hello today im learning python
# it is very intersting
# it is very easy
# i will attend every day

# %%
esc+m ===> code to markdown =====> shift+enter
esc+y =====> markdown to code

# %% [markdown]
# # python

# %% [markdown]
# ## python

# %% [markdown]
# - square brackets indicates the cell is in code mode
# - when square brackets are not there the cell is in markdown mode
# - code mode is used to write a codeing part
# - markdown mode is used for doc of entire dovelepment like a book

# %% [markdown]
# <img src="https://incubator.ucf.edu/wp-content/uploads/2023/07/artificial-intelligence-new-technology-science-futuristic-abstract-human-brain-ai-technology-cpu-central-processor-unit-chipset-big-data-machine-learning-cyber-mind-domination-generative-ai-scaled-1.jpg" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 2560px; height: 203px; margin: 0px; width: 304px;" alt="What is Artificial Intelligence (AI) and Why People Should Learn About it -  UCF Business Incubation Program - University of Central Florida" jsname="kn3ccd">

# %% [markdown]
# ##### python

# %% [markdown]
# <img src="https://filmfare.wwmindia.com/content/2025/may/sriya-reddy-pawan-kalyan-og.jpg" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 900px; height: 362px; margin: 0px; width: 272px;" alt="Sriya Reddy Resumes Shooting For Pawan Kalyan's Film OG | Filmfare.com" jsname="kn3ccd">

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\ganty\\OneDrive\\Documents\\Python_notes\\Python_day_wise'
