# %% [markdown]
# - print function

# %%
n1=100
n2=200
add=n1+n2
print(add)      #trigger
print('the addition of 100 and 200 is 300')
print('the summation of 100 and 200 is 300')
# Out:
# the addition of 100 and 200 is 300
# the summation of 100 and 200 is 300

# %%
# the write up : string quouts (red)
# 1000 and 2000 100 or 200
# stored in variable n1 and n2 (black)

# %%
n1=1000
n2=2000
add=n1+n2
print('the addition of 100 and 200 is 300')
print('the summation of 100 and 200 is 300')
# Out:
# the addition of 100 and 200 is 300
# the summation of 100 and 200 is 300

# %%
n1=1000
n2=2000
add=n1+n2
print('the addition of n1 and n2 is add')
# Out:
# the addition of n1 and n2 is add

# %%
n1=1000
n2=200
add=n1+n2
print('the addition of n1 and n2 is add')
print('the addition of', n1, 'and', n2, 'is', add)  # right way
# Out:
# the addition of n1 and n2 is add
# the addition of 1000 and 200 is 1200

# %%
print('hai',)
print('hello')
print('hai','hello')
print('hai','hello',100)
a=100
print('hai','hello',a)
# Out:
# hai
# hello
# hai hello
# hai hello 100
# hai hello 100

# %%
Name='vijay kumar'
age=22
city='machilipatnam'
print('my name is python im 10 year old. I came from hyderabad')
print('my name is',Name,' im',age,' old. I came from',city)
# Out:
# my name is python im 10 year old. I came from hyderabad
# my name is vijay kumar  im 22  old. I came from machilipatnam

# %%
n1=100
n2=200
add=n1+n2
print('the addition of 100 and 200 is 300')
print('the addition of {} and {} is {}')
print('the addition of {} and {} is {}'.format(n1,n2,add))
# Out:
# the addition of 100 and 200 is 300
# the addition of {} and {} is {}
# the addition of 100 and 200 is 300

# %%
Name='vijay kumar'
age=22
city='machilipatnam'
print('my name is python im 10 year old. I came from hyderabad')
print('my name is {} im {} year old. I came from {}')
print('my name is {} im {} year old. I came from {}'.format(Name,age,city))
# Out:
# my name is python im 10 year old. I came from hyderabad
# my name is {} im {} year old. I came from {}
# my name is vijay kumar im 22 year old. I came from machilipatnam

# %% [markdown]
# **f-string**
#
# - very very easy and most used method

# %%
n1=100
n2=200
add=n1+n2
print(add)      
print('the addition of 100 and 200 is 300')
print(f'the addition of {n1} and {n2} is {add}')
# Out:
# 300
# the addition of 100 and 200 is 300
# the addition of 100 and 200 is 300

# %%
n1=100
n2=200
add=n1-n2
print('the subtraction of {} and {} is {}'.format(n1,n2,add))
add=n1*n2
print(f'the multiplication of {n1} and {n2} is {add}')
add=n1+n2
print(f'the additon of {n1} and {n2} is {add}')
# Out:
# the subtraction of 100 and 200 is -100
# the multiplication of 100 and 200 is 20000
# the additon of 100 and 200 is 300

# %%
pi=3.15
r=100
area=pi*r*r
print('area_of_circle is',area)
# Out:
# area_of_circle is 31500.0

# %%
height=10
breadth=15
area_of_traingle=0.5*breadth*height
print('area of traingle = {}'.format(area_of_traingle))
print(f'area of traingle = {area_of_traingle}')
# Out:
# area of traingle = 75.0
# area of traingle = 75.0

# %%
a=10
b=20
c=30
average=a+b+c/3
print('average ={}'.format(average))
# Out:
# average =40.0

# %%
bill_amount=1500
tip_amount=500
total_bill=bill_amount+tip_amount
print(f'total_bill={total_bill}')
# Out:
# total_bill=2000

# %%
salary=50000
tax=10
tax_amount=salary*tax/100
print('tax_amount= {}'.format(tax_amount))
# Out:
# tax_amount= 5000.0

# %%
pi=3.14
radius=100
area_of_circle=pi*radius*radius
print(
# Out:
#   Cell In[1], line 4
#     print(
#           ^
# _IncompleteInputError: incomplete input

# %%
pi=3.14
radius=100
area_of_circle=pi*radius*radius
print('area of the circle is : {}',format(area_of_circle))
# Out:
# area of the circle is : {} 31400.0

# %%
pi=3.14
radius=100
area_of_circle=pi*radius*radius
print('area of the circle is : {},format(area_of_circle))
# Out:
#   Cell In[4], line 4
#     print('area of the circle is : {},format(area_of_circle))
#           ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
pi=3.14
radius=100
area_of_circle=pi*radius*radius
print('area of the circle is : {}',format(area_of_circle))
# Out:
# area of the circle is : {} 31400.0

# %%
pi=3.14
radius=100
area_of_circle=pi*radius*radius
print('area of the circle is : {}',format(area_of_circel))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 radius=100
#       3 area_of_circle=pi*radius*radius
# ----> 4 print('area of the circle is : {}',format(area_of_circel))
#
# NameError: name 'area_of_circel' is not defined

# %%
pi=3.14
radius=100
area_of_circle=pi*radius*radius
print('area of the circle is : {}',format(area_of_circle))
# Out:
# area of the circle is : {} 31400.0

# %%
print('area of the circle is : {}',format(area_of_circle)
# Out:
#   Cell In[9], line 1
#     print('area of the circle is : {}',format(area_of_circle)
#                                                              ^
# _IncompleteInputError: incomplete input

# %%
print('area of the circle is : {}',format(area_of_circle))
# Out:
# area of the circle is : {} 31400.0

# %%
print(f'area of the circle is : {area_of_circle')
# Out:
#   Cell In[15], line 1
#     print(f'area of the circle is : {area_of_circle')
#                                                    ^
# SyntaxError: f-string: expecting '}'

# %%
print(f'area of the circle is : {area_of_circle}')
# Out:
# area of the circle is : 31400.0
