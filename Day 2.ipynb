# %%
for i in range(10000):
    pass

# %%
import time
time.sleep(5)
print('hai')
# Out:
# hai

# %%
import time
time.sleep(10)
print('hai')
# Out:
# hai

# %%
a=10
print(a) # star mark indicates kernal is busy
# Out:
# 10

# %%
n1=100 # you can not run the kernel not show the answer

# %%
n2=200

# %%
n1+n2

# %%
# python is a step by step process 
# you can write the 10 lines

# %%
import os
os.getcwd() # current working directory
            # we can able see where is the python file avaliable in my loptop
# Out:
# 'C:\\Users\\ganty\\OneDrive\\Documents\\Python_notes\\Python_day_wise'

# %%
for i in range(1, 2, 3):
    print(i)
# Out:
# 1

# %%
for i  in range(1,5,2):
    print(i)
# Out:
# 1
# 3
