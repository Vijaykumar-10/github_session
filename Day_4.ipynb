# %%
salary=100000
tax_persentage=10
find_the_tax=salary*tax_persentage/100
print(find_the_tax)
# Out:
# 10000.0

# %%
1e1
# Out:
# 10.0

# %%
1e-1
# Out:
# 0.1

# %%
1e2
# Out:
# 100.0

# %%
print(1e1,1e+1)
print(1e2,1e+2)
print(2e3,2e+3)
# Out:
# 10.0 10.0
# 100.0 100.0
# 2000.0 2000.0
