# %%
n1=10

# %%
n2=20

# %%
n1+n2
# Out:
# 30

# %%
NUMBER = 100
NUMBER
# Out:
# 100

# %%
number=200
number
# Out:
# 200

# %%
NUMBER,number
# Out:
# (100, 200)

# %%
NUMber=400
NUMber
# Out:
# 400

# %%
NUMBER,number
# Out:
# (100, 200)

# %%
number123=600
number123
# Out:
# 600

# %%
123number=700
123number
# Out:
#   Cell In[14], line 1
#     123number=700
#       ^
# SyntaxError: invalid decimal literal

# %%
num@ber=200
num@ber     # spl charecters are not allowed
# Out:
#   Cell In[15], line 1
#     num@ber=200
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
$number=100
$number        # spl charecters are not allowed
# Out:
#   Cell In[16], line 1
#     $number=100
#     ^
# SyntaxError: invalid syntax

# %%
num_ber=100
num_ber
# Out:
# 100

# %%
area_of_cricle=100
area_of_cricle
# Out:
# 100

# %%
num@ber=200          # F
$number=100        #f
num_ber=200      # w
area of cricle=100  # F
area_of_cricle=200  # W
areaofcricle=300    # W

# %%
_=300
_
# Out:
# 300

# %%
if=100    # if is a keyword
if
# Out:
#   Cell In[20], line 1
#     if=100
#       ^
# SyntaxError: invalid syntax

# %%
sum=200           # sum, max, min, len is in math family
sum
# Out:
# 200

# %%
l=[1,2,3,4]

# %%
print(l)
# Out:
# [1, 2, 3, 4]

# %%
l=[1,2,3,4]
sum(l)
# Out:
# 10

# %%
type(l)
# Out:
# list

# %%
max(l)
# Out:
# 4

# %%
min(l)
# Out:
# 1

# %%
len(l)
# Out:
# 4

# %% [markdown]
# - varibles can be capital and small letters
# - varibles are case sensitive
# - varibles dose not include spl char
# - number as prefix not allowed
# - varibles can have underscore
# - only underscore also possible
# - reserved keywords can not be a variable
# - inbuilt functions can not use as variable

# %%
type=('apple', 'mango', 'banna')
