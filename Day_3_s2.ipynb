# %%
a=10
b=20
c=30
average=(a+b+c)/3
average
# Out:
# 20.0

# %%
r=2
pi=3.14
print(pi*r*r)
# Out:
# 12.56

# %%
bill_amount= 1000
tip_amount = 300
total_bill=bill_amount+tip_amount
print(total_bill)
# Out:
# 1300

# %%
length=100
breath=200
area_of_rectangle=length*breath
area_of_rectangle
# Out:
# 20000

# %%
weight_in_kgs=60
weight_in_pounds=60*2.2
weight_in_pounds
# Out:
# 132.0
